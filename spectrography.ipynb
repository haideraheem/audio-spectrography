# %% [markdown]
# <a href="https://colab.research.google.com/github/haideraheem/audio-spectrography/blob/main/spectrography.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

# %%
x, sr = librosa.load('/content/video_2022-02-24_19-14-31.mp3')

print(type(x), type(sr))
print(x.shape, sr)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# <class 'numpy.ndarray'> <class 'int'>
# (2569796,) 22050

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
fig = plt.figure(figsize=(14, 5))
img = librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
fig.colorbar(img, format="%+2.f dB")
